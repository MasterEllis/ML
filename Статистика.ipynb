# %% [markdown]
# <a href="https://colab.research.google.com/github/MasterEllis/ML/blob/main/%D0%A1%D1%82%D0%B0%D1%82%D0%B8%D1%81%D1%82%D0%B8%D0%BA%D0%B0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# скачиваем набор данных

# !wget https://raw.githubusercontent.com/MasterEllis/datasets/refs/heads/main/numbers.csv

# %%
import numpy as np


# Загружаем данные из CSV файла в NumPy массив
numbers = np.loadtxt("numbers.csv", delimiter=",")

# %% [markdown]
# #Задания
#
# 1. Чему равно среднее значение набора данных? Ответ округлите до целого числа.
# 2. Чему равна медиана набора данных? Ответ округлите до целого числа.
# 3. Чему равна мода набора данных? Ответ округлите до целого числа. Если мод несколько, укажите наименьшую.
# 4. Чему равна несмещенная выборочная дисперсия набора данных?
# Ответ округлите до целого числа.
#
# 5. Постройте гистограмму распределения предоставленного вам набора данных.
# На какое из приведенных ниже распределений больше похожа получившаяся гистограмма?
#
# ![image.png](data:image/png;base64,...)

# %%
# ваш код здесь
